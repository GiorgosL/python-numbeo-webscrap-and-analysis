# %%
from bs4 import BeautifulSoup
import requests
from itertools import chain
import pandas as pd
import re

# %%
def create_frame(city):
    
    total = pd.DataFrame()
    new =  []
    page = requests.get("https://www.numbeo.com/cost-of-living/in/" + city)
    soup = BeautifulSoup(page.content)
    data = soup.find_all("table",{"class":"data_wide_table new_bar_table"})
    data_cost = soup.find_all("span",{"class":"emp_number"})
    cost_index = re.search('>(.*)\<', str(data_cost[5])).group(1)
    
    l = [item.text.split('€') for item in data]
    newlist = list(chain(*l))
    
    new.append('City' + '  '  + city)
    new.append('Cost_index' + '  ' + cost_index)

    for i in range(len(newlist)):
        try:
            new.append(re.search('\n(.*)\xa0', newlist[i]).group(1))
        except AttributeError as e:
            pass



    for i in range(len(new)):
        total = total.append(pd.DataFrame({'':new[i].split('  ')[0], 'Cost':new[i].split('  ')[1]},index=[0]), ignore_index=True)

    headers = total.T.iloc[0]
    df  = pd.DataFrame(total.T.values[1:], columns=headers)
    
    return df

# %%
df1 = create_frame('Athens')
df2 = create_frame('Berlin')
df3 = create_frame('Paris')
df4 = create_frame('Rome')
df5 = create_frame('Vienna')
df6 = create_frame('Milan')
df7 = create_frame('Madrid')
df8 = create_frame('Rome')
df9 = create_frame('Munich')
df10 = create_frame('Barcelona')
df11 = create_frame('Ljubljana')
df12 = create_frame('Amsterdam')
df13 = create_frame('Helsinki')
df14 = create_frame('Stockholm')
df15 = create_frame('London')
df16 = create_frame('Bilbao')
df17 = create_frame('Glasgow')
df18 = create_frame('Bristol')
df19 = create_frame('Warsaw')
df20 = create_frame('Lille')
df21 = create_frame('Porto')
df22 = create_frame('Bucharest')
df23 = create_frame('Hamburg')
df24 = create_frame('Belgrade')
df25 = create_frame('Sofia')
df26 = create_frame('Brussels')
df27 = create_frame('Marseille')

# %%
dfs = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df20,df26,df27]

# %%
[i for i in range(len(dfs)) if dfs[i].shape[1] ==3]
# Out:
# []

# %%
def create_dfs(dfs):
    df = pd.concat(dfs)
    dfc = df['City']
    df = df.iloc[:, 1:-1].apply(pd.to_numeric, errors='coerce').dropna(axis=1)
    df.insert(loc=0, column='City', value=dfc.values)
    return df

# %%
create_dfs(dfs)
# Out:
#         City  Cost_index  Meal, Inexpensive Restaurant  \
# 0     Athens       55.70                         10.00
# 0     Berlin       62.63                          9.00
# 0      Paris       84.38                         15.00
# 0       Rome       69.03                         15.00
# 0     Vienna       64.12                         10.00
# 0      Milan       74.94                         15.00
# 0     Madrid       58.30                         12.00
# 0       Rome       69.03                         15.00
# 0     Munich       71.23                         13.00
# 0  Barcelona       57.34                         11.50
# 0  Ljubljana       54.08                          8.50
# 0      Lille       67.98                         12.75
# 0   Brussels       68.97                         15.00
# 0  Marseille       71.08                         13.50
#
#    Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                