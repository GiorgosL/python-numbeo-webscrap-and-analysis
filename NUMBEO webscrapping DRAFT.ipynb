# %%
from bs4 import BeautifulSoup
import requests
from itertools import chain
import pandas as pd
import re

# %%
def create_frame(city):
    
    total = pd.DataFrame()
    new =  []
    page = requests.get("https://www.numbeo.com/cost-of-living/in/" + city)
    soup = BeautifulSoup(page.content)
    data = soup.find_all("table",{"class":"data_wide_table new_bar_table"})
    data_cost = soup.find_all("span",{"class":"emp_number"})
    cost_index = re.search('>(.*)\<', str(data_cost[5])).group(1)
    
    l = [item.text.split('€') for item in data]
    newlist = list(chain(*l))

    for i in range(len(newlist)):
        try:
            new.append(re.search('\n(.*)\xa0', newlist[i]).group(1))
        except AttributeError as e:
            pass

    new.append('City' + '  '  + city)
    new.append('Cost_index' + '  ' + cost_index)

    for i in range(len(new)):
        total = total.append(pd.DataFrame({'':new[i].split('  ')[0], 'Cost':new[i].split('  ')[1]},index=[0]), ignore_index=True)

    headers = total.T.iloc[0]
    df  = pd.DataFrame(total.T.values[1:], columns=headers)
    
    return df

# %%
df1 = create_frame('Athens')
df2 = create_frame('Berlin')
df3 = create_frame('Paris')
df4 = create_frame('Rome')
df5 = create_frame('Vienna')
df6 = create_frame('Milan')
df7 = create_frame('Madrid')
df8 = create_frame('Rome')
df9 = create_frame('Munich')
df10 = create_frame('Barcelona')

df_f = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10])

# %%
df_f
# Out:
#    Meal, Inexpensive Restaurant  \
# 0                          10.0
# 0                           9.0
# 0                          15.0
# 0                          15.0
# 0                          10.0
# 0                          15.0
# 0                          12.0
# 0                          15.0
# 0                          13.0
# 0                          11.5
#
#   Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                              40.00
# 0                                              40.00
# 0                                              52.50
# 0                                              60.00
# 0                                              47.00
# 0                                              60.00
# 0                                              50.00
# 0                                              60.00
# 0                                              62.50
# 0                                              45.00
#
#   McMeal at McDonalds (or Equivalent Combo Meal)  \
# 0                                           6.15
# 0                                           8.00
# 0                                           9.00
# 0                                           8.00
# 0                                           7.25
# 0                                           8.00
# 0                                           8.00
# 0                                           8.00
# 0                                           8.00
# 0                                           8.00
#
#   Domestic Beer (0.5 liter draught) Imported Beer (0.33 liter bottle)  \
# 0                              4.00                              4.50
# 0                              3.50                              3.50
# 0                              7.00                              6.00
# 0                              5.00                              4.00
# 0                              4.00                              4.00
# 0                              5.00                              5.00
# 0                              3.00                              3.50
# 0                              5.00                              4.00
# 0                              3.90                              4.00
# 0                              2.75                              3.00
#
#   Cappuccino (regular) Coke/Pepsi (0.33 liter bottle)  \
# 0                 3.24                           1.71
# 0                 2.80                           2.02
# 0                 3.50                           3.01
# 0                 1.24                           1.87
# 0                 3.30                           2.85
# 0                 1.51                           2.54
# 0                 1.86                           1.93
# 0                 1.24                           1.87
# 0                 3.06                           2.87
# 0                 1.78                           1.74
#
#   Water (0.33 liter bottle) Milk (regular), (1 liter)  \
# 0                                                1.30
# 0                                                0.90
# 0                                                1.22
# 0                                                1.27
# 0                                                1.08
# 0                                                1.23
# 0                                                0.83
# 0                                                1.27
# 0                                                0.92
# 0                                                0.87
#
#   Loaf of Fresh White Bread (500g)  ... 1 Pair of Men Leather Business Shoes  \
# 0                             0.81  ...                                92.17
# 0                             1.33  ...                               106.21
# 0                             1.65  ...                               130.87
# 0                             1.59  ...                               115.48
# 0                             1.86  ...                               117.10
# 0                             2.05  ...                               137.39
# 0                             1.12  ...                                91.80
# 0                             1.59  ...                               115.48
# 0                             1.71  ...                               126.53
# 0                             1.09  ...                                94.62
#
#   Apartment (1 bedroom) in City Centre  \
# 0                               408.65
# 0                               920.59
# 0                             1,194.71
# 0                               943.68
# 0                               873.14
# 0                             1,133.18
# 0                               992.79
# 0                               943.68
# 0                             1,268.01
# 0                               957.92
#
#   Apartment (1 bedroom) Outside of Centre  \
# 0                                  351.79
# 0                                  671.20
# 0                                  875.88
# 0                                  653.49
# 0                                  643.31
# 0                                  748.83
# 0                                  732.95
# 0                                  653.49
# 0                                  906.10
# 0                                  730.07
#
#   Apartment (3 bedrooms) in City Centre  \
# 0                                732.26
# 0                              1,710.48
# 0                              2,603.85
# 0                              1,820.59
# 0                              1,597.89
# 0                              2,455.44
# 0                              1,734.91
# 0                              1,820.59
# 0                              2,275.44
# 0                              1,522.14
#
#   Apartment (3 bedrooms) Outside of Centre  \
# 0                                   640.26
# 0                                 1,224.92
# 0                                 1,745.00
# 0                                 1,147.38
# 0                                 1,160.23
# 0                                 1,514.52
# 0                                 1,196.46
# 0                                 1,147.38
# 0                                 1,736.21
# 0                                 1,085.82
#
#   Price per Square Meter to Buy Apartment in City Centre  \
# 0                                           2,054.18
# 0                                           5,795.06
# 0                                          11,441.32
# 0                                           6,690.00
# 0                                           7,069.89
# 0                                           8,517.59
# 0                                           5,170.73
# 0                                           6,690.00
# 0                                          11,114.71
# 0                                           4,524.33
#
#   Price per Square Meter to Buy Apartment Outside of Centre  \
# 0                                           1,938.06
# 0                                           3,762.96
# 0                                           8,701.54
# 0                                           3,033.33
# 0                                           4,241.62
# 0                                           3,781.61
# 0                                           3,140.47
# 0                                           3,033.33
# 0                                           7,765.15
# 0                                           3,142.59
#
#   Average Monthly Net Salary (After Tax)       City Cost_index
# 0                                 777.28     Athens      55.65
# 0                               2,505.78     Berlin      62.49
# 0                               2,231.02      Paris      84.38
# 0                               1,488.44       Rome      69.03
# 0                               2,089.24     Vienna      64.12
# 0                               1,649.63      Milan      75.03
# 0                               1,639.67     Madrid      58.30
# 0                               1,488.44       Rome      69.03
# 0                               2,727.80     Munich      71.07
# 0                               1,440.27  Barcelona      57.34
#
# [10 rows x 56 columns]
